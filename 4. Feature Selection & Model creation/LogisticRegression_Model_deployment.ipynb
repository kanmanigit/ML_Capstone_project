# %%
# Model Deployment 

import pandas as pd
import pickle as pk

# %%
dataset=pd.read_csv("prep_ds.csv")


## load the model
loaded_medel = pk.load(open("logisticR_finalized_model","rb"))

## load the standardsclar obj
scx = pk.load(open("scx","rb"))
dataset
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     47        140       267.00          0    156      0.0             0
# 1     49        140       180.00          0    156      1.0             1
# 2     47        130       267.00          0    120      0.0             0
# 3     48        138       214.00          0    120      1.5             1
# 4     54        140       195.00          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   47        120       264.00          0    132      1.2             1
# 914   60        140       193.00          0    141      1.5             1
# 915   57        130       173.25          0    120      1.2             1
# 916   57        130       236.00          0    156      0.0             1
# 917   47        138       175.00          0    156      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
pre_input= scx.transform([[156,0,1]])
loaded_medel.predict(pre_input)
# Out:
# array([0])
