# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/Users/kanmaniramasamy/Documents/HopeAI_Tamil/week10_ML_DatascienceAssignment_Capstone_project/heart.csv")
dataset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
# Separation of Quan and Qual columns
quan_columns = []
qual_columns = []
for columnName in dataset.columns:
    if dataset[columnName].dtype=="object":
        qual_columns.append(columnName)
    else:
        quan_columns.append(columnName)

# %%
quan_columns
# Out:
# ['Age',
#  'RestingBP',
#  'Cholesterol',
#  'FastingBS',
#  'MaxHR',
#  'Oldpeak',
#  'HeartDisease']

# %%
qual_columns
# Out:
# ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

# %%
## how many Males and females have Heart disease? (Categorical col)

sns.countplot(dataset,x="Sex",hue="HeartDisease")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# how many percentage of Males and Females have Heart disease? (Categorical col)

dataset["Sex"].value_counts().plot(kind="pie", autopct="%1.2f %%")  # "%1.2f %%" 2decimal points after period...
# Out:
# <Axes: ylabel='count'>

# %%
## what is the types of chestpain? (Categorical col)

dataset["ChestPainType"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='ChestPainType'>

# %%
# Find the distribution of "Cholestral" (Numerical Col)

sns.distplot(dataset["Cholesterol"])
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/788897844.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Cholesterol"])
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
# Find the distribution of Age (Numerical cols)

sns.distplot(dataset["Age"])
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/3525963365.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# finding the skewness and plot it 
dataset["Cholesterol"].skew()
# Out:
# -0.6100864307268192

# %%
sns.distplot(dataset["Cholesterol"])
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/3957430249.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Cholesterol"])
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
# Find if any ouliers on the "Cholesterol" column...

sns.boxplot(dataset['Cholesterol'])
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
# Find Skewness of Resting BP
dataset["RestingBP"].skew()
# Out:
# 0.1798393100516288

# %%
sns.distplot(dataset["RestingBP"])
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/751498858.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["RestingBP"])
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
num_col=dataset[quan_columns]
num_col
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
# [918 rows x 7 columns]

# %%
#Plot histogram for each numeric features

for col in dataset[quan_columns]:
   
    plt.figure() # create a new fig for each plot
    plt.hist(dataset[col])
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
### #Plot pdf for each numeric features

for col in dataset[quan_columns]:
    sns.distplot(dataset[col])
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/39553084.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset[col])
# /var/folders/1s/70xy4dvs6mn0zqfz6nvhbypw0000gn/T/ipykernel_33585/39553084.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# Find Skewness of all the numerical feature..

for col in dataset[quan_columns]:
    sk=dataset[col].skew()
    print(f'Skew of {col}: ',sk)
# Out:
# Skew of Age:  -0.19593302867569365
# Skew of RestingBP:  0.1798393100516288
# Skew of Cholesterol:  -0.6100864307268192
# Skew of FastingBS:  1.2644841750727027
# Skew of MaxHR:  -0.14435941846180994
# Skew of Oldpeak:  1.0228720218107528
# Skew of HeartDisease:  -0.21508633825088655

# %% [markdown]
# ## Bivariant analysis

# %%
### Bivariant Analysis
# does Cholestrol  affect the Heart Disease ? (Numerical -numerical)
sns.scatterplot(x=dataset["Cholesterol"],y=dataset["HeartDisease"])
# Out:
# <Axes: xlabel='Cholesterol', ylabel='HeartDisease'>

# %%
# Average value of each feature for target

target="HeartDisease"
for i in quan_columns:
    plt.figure(figsize=(12,6))
    sns.barplot(dataset[quan_columns], x=i,y=target,estimator='mean')
